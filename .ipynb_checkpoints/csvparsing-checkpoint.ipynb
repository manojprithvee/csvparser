# %%
import csv,itertools

reader = csv.DictReader(itertools.islice(open("MGT 01 Spring '19 - Copy_October 15, 2019_11.33.csv"), 1, None))
outputarray=[]
total={}
for row in reader:
    name=""
    team=""
    for a in row:
        temp=[]
        if row[a]!="":
            if "Select your team" in a:
                team=row[a]
            if "Select Your Name" in a:
                name=row[a]
            elif "-" in a:
                abc=a.split(" - ")
                if len(abc)==2 and "ImportId" not in name:
                    if a.split(" - ")[0] not in total:
                        total[a.split(" - ")[0]]=[a.split(" - ")[0],0]
                    temp.append(a.split(" - ")[0])
                    temp.append(name)
                    temp.append(team)
                    temp.append(a.split(" - ")[1])
                    temp.append(row[a])
                    try:
                        total[a.split(" - ")[0]][1]+=int(row[a].split(".")[0])
                    except:
                        total[a.split(" - ")[0]].append(row[a])
                    outputarray.append(temp)
outputarray.sort(key = lambda x: x[2]) 
outputarray=[["name","by","team","Question","Answer","score"]]+outputarray

with open("output.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(outputarray)
with open("score.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(total.values())

# %%
import pandas as pd
pd.DataFrame(outputarray)
# Out:
#                         0                   1        2  \
# 0                    name                  by     team
# 1           Correia, Kyle     Anderson, Tyler  Andrews
# 2           Correia, Kyle     Anderson, Tyler  Andrews
# 3           Correia, Kyle     Anderson, Tyler  Andrews
# 4           Correia, Kyle     Anderson, Tyler  Andrews
# 5           Correia, Kyle     Anderson, Tyler  Andrews
# 6           Correia, Kyle     Anderson, Tyler  Andrews
# 7           Correia, Kyle     Anderson, Tyler  Andrews
# 8        Peterson, Austin     Anderson, Tyler  Andrews
# 9        Peterson, Austin     Anderson, Tyler  Andrews
# 10       Peterson, Austin     Anderson, Tyler  Andrews
# 11       Peterson, Austin     Anderson, Tyler  Andrews
# 12       Peterson, Austin     Anderson, Tyler  Andrews
# 13       Peterson, Austin     Anderson, Tyler  Andrews
# 14       Peterson, Austin     Anderson, Tyler  Andrews
# 15         Revier, Joshua     Anderson, Tyler  Andrews
# 16         Revier, Joshua     Anderson, Tyler  Andrews
# 17         Revier, Joshua     Anderson, Tyler  Andrews
# 18         Revier, Joshua     Anderson, Tyler  Andrews
# 19         Revier, Joshua     Anderson, Tyler  Andrews
# 20         Revier, Joshua     Anderson, Tyler  Andrews
# 21         Revier, Joshua     Anderson, Tyler  Andrews
# 22           Torres, Evan     Anderson, Tyler  Andrews
# 23           Torres, Evan     Anderson, Tyler  Andrews
# 24           Torres, Evan     Anderson, Tyler  Andrews
# 25           Torres, Evan     Anderson, Tyler  Andrews
# 26           Torres, Evan     Anderson, Tyler  Andrews
# 27           Torres, Evan     Anderson, Tyler  Andrews
# 28           Torres, Evan     Anderson, Tyler  Andrews
# 29          Correia, Kyle     Anderson, Tyler  Andrews
# ..                    ...                 ...      ...
# 111         Royal, Delina   Bumpus, Mackenzie  Chester
# 112         Royal, Delina   Bumpus, Mackenzie  Chester
# 113        Cross, Zachary  Ferreira, Jonathon   Ferris
# 114        Cross, Zachary  Ferreira, Jonathon   Ferris
# 115        Cross, Zachary  Ferreira, Jonathon   Ferris
# 116        Cross, Zachary  Ferreira, Jonathon   Ferris
# 117        Cross, Zachary  Ferreira, Jonathon   Ferris
# 118        Cross, Zachary  Ferreira, Jonathon   Ferris
# 119        Cross, Zachary  Ferreira, Jonathon   Ferris
# 120        He, Chengcheng  Ferreira, Jonathon   Ferris
# 121        He, Chengcheng  Ferreira, Jonathon   Ferris
# 122        He, Chengcheng  Ferreira, Jonathon   Ferris
# 123        He, Chengcheng  Ferreira, Jonathon   Ferris
# 124        He, Chengcheng  Ferreira, Jonathon   Ferris
# 125        He, Chengcheng  Ferreira, Jonathon   Ferris
# 126        He, Chengcheng  Ferreira, Jonathon   Ferris
# 127       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 128       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 129       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 130       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 131       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 132       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 133       Reardon, Daniel  Ferreira, Jonathon   Ferris
# 134  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 135  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 136  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 137  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 138  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 139  van der Meer, Olivia  Ferreira, Jonathon   Ferris
# 140  van der Meer, Olivia  Ferreira, Jonathon   Ferris
#
#                                                      3  \
# 0                                             Question
# 1              Rate [Field-1] on Simulation Knowledge.
# 2    Rate [Field-1] on willingness to cooperate wit...
# 3    Rate [Field-1] on Attendance at Lab Session/Te...
# 4                        Rate [Field-1] on Leadership.
# 5          Rate [Field-1] on Attitude Towards Project.
# 6                Rate [Field-1] on Overall evaluation.
# 7    Important: Please provide at least a couple of...
# 8              Rate [Field-1] on Simulation Knowledge.
# 9    Rate [Field-1] on willingness to cooperate wit...
# 10   Rate [Field-1] on Attendance at Lab Session/Te...
# 11                       Rate [Field-1] on Leadership.
# 12         Rate [Field-1] on Attitude Towards Project.
# 13               Rate [Field-1] on Overall evaluation.
# 14   Important: Please provide at least a couple of...
# 15             Rate [Field-1] on Simulation Knowledge.
# 16   Rate [Field-1] on willingness to cooperate wit...
# 17   Rate [Field-1] on Attendance at Lab Session/Te...
# 18                       Rate [Field-1] on Leadership.
# 19         Rate [Field-1] on Attitude Towards Project.
# 20               Rate [Field-1] on Overall evaluation.
# 21   Important: Please provide at least a couple of...
# 22             Rate [Field-1] on Simulation Knowledge.
# 23   Rate [Field-1] on willingness to cooperate wit...
# 24   Rate [Field-1] on Attendance at Lab Session/Te...
# 25                       Rate [Field-1] on Leadership.
# 26         Rate [Field-1] on Attitude Towards Project.
# 27               Rate [Field-1] on Overall evaluation.
# 28   Important: Please provide at least a couple of...
# 29             Rate [Field-1] on Simulation Knowledge.
# ..                                                 ...
# 111              Rate [Field-1] on Overall evaluation.
# 112  Important: Please provide at least a couple of...
# 113            Rate [Field-1] on Simulation Knowledge.
# 114  Rate [Field-1] on willingness to cooperate wit...
# 115  Rate [Field-1] on\nAttendance at Lab Sessions/...
# 116                      Rate [Field-1] on Leadership.
# 117        Rate [Field-1] on Attitude Towards Project.
# 118               Rate [Field-1] on Overall evalution.
# 119  Important: Please provide at least a couple of...
# 120            Rate [Field-1] on Simulation Knowledge.
# 121  Rate [Field-1] on willingness to cooperate wit...
# 122  Rate [Field-1] on\nAttendance at Lab Sessions/...
# 123                      Rate [Field-1] on Leadership.
# 124        Rate [Field-1] on Attitude Towards Project.
# 125               Rate [Field-1] on Overall evalution.
# 126  Important: Please provide at least a couple of...
# 127            Rate [Field-1] on Simulation Knowledge.
# 128  Rate [Field-1] on willingness to cooperate wit...
# 129  Rate [Field-1] on\nAttendance at Lab Sessions/...
# 130                      Rate [Field-1] on Leadership.
# 131        Rate [Field-1] on Attitude Towards Project.
# 132               Rate [Field-1] on Overall evalution.
# 133  Important: Please provide at least a couple of...
# 134            Rate [Field-1] on Simulation Knowledge.
# 135  Rate [Field-1] on willingness to cooperate wit...
# 136  Rate [Field-1] on\nAttendance at Lab Sessions/...
# 137                      Rate [Field-1] on Leadership.
# 138        Rate [Field-1] on Attitude Towards Project.
# 139               Rate [Field-1] on Overall evalution.
# 140  Important: Please provide at least a couple of...
#
#                                                      4      5
# 0                                               Answer  score
# 1    2. Meets Standards.  Came to lab sessions mode...   None
# 2    1. Fails to meet Standards. Showed limited abi...   None
# 3    1. Fails to meet Standards.  At lab sessions/t...   None
# 4    1. Fails to meet Standards.  Showed no leaders...   None
# 5    1. Fails to meet Standards.  Exhibited a negat...   None
# 6    1. Fails to meet Standards. Would definitely w...   None
# 7                                                  jaj   None
# 8    2. Meets Standards.  Came to lab sessions mode...   None
# 9    1. Fails to meet Standards. Showed limited abi...   None
# 10   3. Exceeds Standards.  At lab sessions/team me...   None
# 11   2.  Meets Standards.  Sometimes showed leaders...   None
# 12   2. Meets Standards.  Exhibited a modestly posi...   None
# 13   2. Meets Standards. Might work with this perso...   None
# 14                                                kjhb   None
# 15   1. Fails to meet Standards.  Came to lab sessi...   None
# 16   1. Fails to meet Standards. Showed limited abi...   None
# 17   2. Meets Standards.  At lab sessions/team meet...   None
# 18   2.  Meets Standards.  Sometimes showed leaders...   None
# 19   1. Fails to meet Standards.  Exhibited a negat...   None
# 20   1. Fails to meet Standards. Would definitely w...   None
# 21                                                  kb   None
# 22   1. Fails to meet Standards.  Came to lab sessi...   None
# 23   1. Fails to meet Standards. Showed limited abi...   None
# 24   1. Fails to meet Standards.  At lab sessions/t...   None
# 25   1. Fails to meet Standards.  Showed no leaders...   None
# 26   2. Meets Standards.  Exhibited a modestly posi...   None
# 27   2. Meets Standards. Might work with this perso...   None
# 28                                              ,jbbn    None
# 29   2. Meets Standards.  Came to lab sessions mode...   None
# ..                                                 ...    ...
# 111  1. Fails to meet Standards. Would definitely n...   None
# 112                                                 hi   None
# 113  3. Exceeds Standards.  Came to lab sessions we...   None
# 114  3. Exceeds Standards.  Showed strong ability t...   None
# 115  3. Exceeds Standards.  At lab sessions/team me...   None
# 116  3. Exceeds Standards.  Showed exceptional lead...   None
# 117  3.  Exceeds Standards.  Exhibited a strong pos...   None
# 118  2. Meets Standards. Might work with this perso...   None
# 119                                                 hi   None
# 120  3. Exceeds Standards.  Came to lab sessions we...   None
# 121  3. Exceeds Standards.  Showed strong ability t...   None
# 122  2. Meets Standards.  At lab sessions/team meet...   None
# 123  2.  Meets Standards.  Sometimes showed leaders...   None
# 124  2. Meets Standards.  Exhibited a modestly posi...   None
# 125  2. Meets Standards. Might work with this perso...   None
# 126                                                 hi   None
# 127  1. Fails to meet Standards.  Came to lab sessi...   None
# 128  3. Exceeds Standards.  Showed strong ability t...   None
# 129  3. Exceeds Standards.  At lab sessions/team me...   None
# 130  2.  Meets Standards.  Sometimes showed leaders...   None
# 131  3.  Exceeds Standards.  Exhibited a strong pos...   None
# 132  3. Exceeds Standards. Would definitely work wi...   None
# 133                                                 hi   None
# 134  2. Meets Standards.  Came to lab sessions mode...   None
# 135  2. Meets Standards.  Showed modest ability to ...   None
# 136  2. Meets Standards.  At lab sessions/team meet...   None
# 137  3. Exceeds Standards.  Showed exceptional lead...   None
# 138  3.  Exceeds Standards.  Exhibited a strong pos...   None
# 139  2. Meets Standards. Might work with this perso...   None
# 140                                                 hi   None
#
# [141 rows x 6 columns]

# %%
from flask import Flask, render_template, request
from werkzeug import secure_filename
app = Flask(__name__)

@app.route('/uploader', methods = ['GET', 'POST'])
def upload_file():
   if request.method == 'POST':
      f = request.files['file']
      f.save(secure_filename(f.filename))
      return 'file uploaded successfully'
if __name__ == '__main__':
   app.run(debug = True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-e0fb5bc5073b> in <module>
#       6 def upload_file():
#       7    return render_template('upload.html')
# ----> 8 @app.route('/uploader', methods = ['GET', 'POST'])
#       9 def upload_file():
#      10    if request.method == 'POST':
#
# //anaconda3/lib/python3.7/site-packages/flask/app.py in decorator(f)
#    1312         def decorator(f):
#    1313             endpoint = options.pop("endpoint", None)
# -> 1314             self.add_url_rule(rule, endpoint, f, **options)
#    1315             return f
#    1316
#
# //anaconda3/lib/python3.7/site-packages/flask/app.py in wrapper_func(self, *args, **kwargs)
#      96                 "before the application starts serving requests."
#      97             )
# ---> 98         return f(self, *args, **kwargs)
#      99
#     100     return update_wrapper(wrapper_func, f)
#
# //anaconda3/lib/python3.7/site-packages/flask/app.py in add_url_rule(self, rule, endpoint, view_func, provide_automatic_options, **options)
#    1281                 raise AssertionError(
#    1282                     "View function mapping is overwriting an "
# -> 1283                     "existing endpoint function: %s" % endpoint
#    1284                 )
#    1285             self.view_functions[endpoint] = view_func
#
# AssertionError: View function mapping is overwriting an existing endpoint function: upload_file

# %% [markdown]
# WAW -> output dep / name Dep\
# RAW -> true dep/ data flow Dep\
# WAR -> Anti dep
